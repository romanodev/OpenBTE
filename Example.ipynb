# %% [markdown]
# <a href="https://colab.research.google.com/github/romanodev/OpenBTE/blob/master/Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf OpenBTE && git clone -q https://github.com/romanodev/OpenBTE.git && cd OpenBTE && python setup.py develop
# !apt-get -qq install -y libgmsh-dev

# %%
from openbte import Material,Geometry,Solver,Plot
Material(model='unlisted',file_id = '1wJy8zWkmGnUFgXsp8st94G0Qo3Nqa0HC');
base = [[ 3.01078268e-01, 2.21429016e-01],
[ 4.46707106e-01, -3.60827374e-01],
[-1.10472045e-01, 3.89017984e-01],
[-3.83525265e-01, -7.68582568e-02],
[-1.55493656e-01, -2.02056697e-01],
[-1.31058618e-01, -2.22113975e-01],
[ 3.88037974e-01, -1.46767846e-01],
[ 4.50174513e-01, 3.37519639e-01],
[ 4.26771368e-01, 4.01421211e-01],
[-1.21785435e-01, -3.39898399e-01]]
geo = Geometry(porosity=0.3,lx=100,ly=100,step=10,shape='square',base=base,lz=0,save=False);
sol = Solver(geometry=geo);
kappa = sol.state['kappa'][-1]
Plot(model='maps',geometry=geo);
# Out:
# Downloading 1wJy8zWkmGnUFgXsp8st94G0Qo3Nqa0HC into ./material.h5...
# 32.0 KiB Done.
#
#         ___                   ____ _____ _____
#        / _ \ _ __   ___ _ __ | __ )_   _| ____|
#       | | | | '_ \ / _ \ '_ \|  _ \ | | |  _|
#       | |_| | |_) |  __/ | | | |_) || | | |___
#        \___/| .__/ \___|_| |_|____/ |_| |_____|
#             |_|
#
#                        GENERAL INFO
#  -----------------------------------------------------------
#   Contact:          romanog@mit.edu
#   Source code:      https://github.com/romanodev/OpenBTE
#   Become a sponsor: https://github.com/sponsors/romanodev
#   Cloud:            https://shorturl.at/cwDIP
#   Mailing List:     https://shorturl.at/admB0
#  -----------------------------------------------------------
#
#                         SYSTEM INFO
#  -----------------------------------------------------------
#   Space Discretization:                    492
#   Momentum Discretization:                 2400
#   Bulk Thermal Conductivity [W/m/K]:       143.1085
#   Fourier Thermal Conductivity [W/m/K]:    122.8277
#  -----------------------------------------------------------
#
#       Iter    Thermal Conductivity [W/m/K]      Error
#  -----------------------------------------------------------
#        1               1.8652E+01             5.5852E+00
#        2               1.4999E+01             2.4359E-01
#        3               1.6047E+01             6.5331E-02
#        4               1.5475E+01             3.6976E-02
#        5               1.5666E+01             1.2236E-02
#        6               1.5558E+01             6.9454E-03
#  -----------------------------------------------------------
#
#                  OpenBTE ended successfully
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id1"></div>
