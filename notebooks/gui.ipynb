# %%
from openbte.gui import *
# Out:
# interactive(children=(FloatSlider(value=0.2, continuous_update=False, description='Porosity:', max=0.3, min=0.…
# interactive(children=(BoundedFloatText(value=150.0, description='TC Matrix [W/K/m]', layout=Layout(width='300p…
# interactive(children=(Select(description='Variable', options=('Geometry', ' '), value='Geometry'), Output()), …
# ...
#
#   ___                   ____ _____ _____
#  / _ \ _ __   ___ _ __ | __ )_   _| ____|
# | | | | '_ \ / _ \ '_ \|  _ \ | | |  _|
# | |_| | |_) |  __/ | | | |_) || | | |___
#  \___/| .__/ \___|_| |_|____/ |_| |_____|
#       |_|
#
# Giuseppe Romano [romanog@mit.edu]
#
#
# Elements:          228
# Azimuthal angles:  16
# Polar angles:      48
# Mean-free-paths:   1
# Degree-of-freedom: 175104
#
# Matrix           100.00 W/m/K
#
# Thermal Conductivity:    63.22 W/m/K
#
#
# Solving BTE... started
#
#     Iter    Thermal Conductivity [W/m/K]      Error       Zeroth - Fourier - BTE
# ...
